# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from moabb.datasets import Gao2026
from moabb.paradigms import MotorImagery
import numpy as np
import matplotlib.pyplot as plt

# %%
"""
Yields optimal training and testing loaders for Cross-Subject (LOSO) validation.
The test_subject_id is 'left out' for evaluation.
"""
n_classes = 10
dataset = Gao2026()
paradigm = MotorImagery(n_classes=n_classes, fmin=4, fmax=38, resample=500)

# 1. Fetch data for all subjects that completed 2 sessions (9 and 10 didn't)
# subjects = list(range(1, 23))
# subjects.pop(8)
# subjects.pop(8)
subjects = [1]
X, y, metadata = paradigm.get_data(
    dataset=dataset, subjects=subjects)  # type: ignore
# Out:
# Choosing from all possible events
